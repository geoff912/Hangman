# %%
import random

easy_words = ["python", "variable", "loop", "list"]
medium_words = ["function", "conditional", "module", "class"]
hard_words = ["dictionary", "object", "recursion", "inheritance"]

def choose_word(difficulty):
    if difficulty == "easy":
        return random.choice(easy_words)
    elif difficulty == "medium":
        return random.choice(medium_words)
    elif difficulty == "hard":
        return random.choice(hard_words)
    else:
        raise ValueError("Invalid difficulty level")

def initialize_game():
    global word_to_guess, guessed_letters, max_guesses, incorrect_guesses, display_word

    difficulty = input("Choose a difficulty level (easy, medium, hard): ").lower()
    word_to_guess = choose_word(difficulty)

    guessed_letters = []
    max_guesses = 10
    incorrect_guesses = 0
    display_word = ["_"] * len(word_to_guess)

def display_current_state():
    print(" ".join(display_word))
    print(f"Guessed letters: {' '.join(guessed_letters)}")
    print(f"Guesses left: {max_guesses - incorrect_guesses}")

while True:
    initialize_game()

    while True:
        display_current_state()

        if "_" not in display_word:
            print("Congratulations! You've guessed the word correctly.")
            break

        if incorrect_guesses >= max_guesses:
            print("You've run out of guesses. The word was:", word_to_guess)
            break

        guess = input("Guess a letter: ").lower()

        if len(guess) != 1 or not guess.isalpha():
            print("Please enter a single letter.")
            continue

        if guess in guessed_letters:
            print("You've already guessed that letter.")
            continue

        guessed_letters.append(guess)

        if guess in word_to_guess:
            for i in range(len(word_to_guess)):
                if word_to_guess[i] == guess:
                    display_word[i] = guess
        else:
            incorrect_guesses += 1
# Out:
# _ _ _ _
# Guessed letters:
# Guesses left: 10
# _ _ _ _
# Guessed letters: a
# Guesses left: 9
# _ _ _ _
# Guessed letters: a e
# Guesses left: 8
# _ _ _ _
# Guessed letters: a e i
# Guesses left: 7
# _ o o _
# Guessed letters: a e i o
# Guesses left: 7
# l o o _
# Guessed letters: a e i o l
# Guesses left: 7
# l o o p
# Guessed letters: a e i o l p
# Guesses left: 7
# Congratulations! You've guessed the word correctly.
# _ _ _ _ _ _
# Guessed letters:
# Guesses left: 10
# _ _ _ _ _ _
# Guessed letters: a
# Guesses left: 9
# _ _ _ e _ _
# Guessed letters: a e
# Guesses left: 9
# o _ _ e _ _
# Guessed letters: a e o
# Guesses left: 9
# o b _ e _ _
# Guessed letters: a e o b
# Guesses left: 9
# o b _ e _ _
# Guessed letters: a e o b g
# Guesses left: 8
# o b _ e _ _
# Guessed letters: a e o b g h
# Guesses left: 7
# o b j e _ _
# Guessed letters: a e o b g h j
# Guesses left: 7
# o b j e _ _
# Guessed letters: a e o b g h j k
# Guesses left: 6
# o b j e _ _
# Guessed letters: a e o b g h j k l
# Guesses left: 5
# You've already guessed that letter.
# o b j e _ _
# Guessed letters: a e o b g h j k l
# Guesses left: 5
# You've already guessed that letter.
# o b j e _ _
# Guessed letters: a e o b g h j k l
# Guesses left: 5
# You've already guessed that letter.
# o b j e _ _
# Guessed letters: a e o b g h j k l
# Guesses left: 5
# You've already guessed that letter.
# o b j e _ _
# Guessed letters: a e o b g h j k l
# Guesses left: 5
# o b j e _ _
# Guessed letters: a e o b g h j k l r
# Guesses left: 4
# o b j e _ t
# Guessed letters: a e o b g h j k l r t
# Guesses left: 4
# o b j e _ t
# Guessed letters: a e o b g h j k l r t y
# Guesses left: 3
# o b j e _ t
# Guessed letters: a e o b g h j k l r t y u
# Guesses left: 2
# o b j e _ t
# Guessed letters: a e o b g h j k l r t y u n
# Guesses left: 1
# o b j e _ t
# Guessed letters: a e o b g h j k l r t y u n v
# Guesses left: 0
# You've run out of guesses. The word was: object
# _ _ _ _ _ _
# Guessed letters:
# Guesses left: 10
